# %%
# Install the gdown Library
# !pip install -U gdown
# Out:
# Requirement already satisfied: gdown in D:\-PROJECTS\venvs\time_series_forecasting_win_venv\Lib\site-packages (6.0.0)
# Requirement already satisfied: beautifulsoup4 in D:\-PROJECTS\venvs\time_series_forecasting_win_venv\Lib\site-packages (from gdown) (4.14.3)
# Requirement already satisfied: filelock in D:\-PROJECTS\venvs\time_series_forecasting_win_venv\Lib\site-packages (from gdown) (3.29.0)
# Requirement already satisfied: requests[socks] in D:\-PROJECTS\venvs\time_series_forecasting_win_venv\Lib\site-packages (from gdown) (2.33.1)
# Requirement already satisfied: tqdm in D:\-PROJECTS\venvs\time_series_forecasting_win_venv\Lib\site-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>=1.6.1 in D:\-PROJECTS\venvs\time_series_forecasting_win_venv\Lib\site-packages (from beautifulsoup4->gdown) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in D:\-PROJECTS\venvs\time_series_forecasting_win_venv\Lib\site-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\-PROJECTS\venvs\time_series_forecasting_win_venv\Lib\site-packages (from requests[socks]->gdown) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in D:\-PROJECTS\venvs\time_series_forecasting_win_venv\Lib\site-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in D:\-PROJECTS\venvs\time_series_forecasting_win_venv\Lib\site-packages (from requests[socks]->gdown) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in D:\-PROJECTS\venvs\time_series_forecasting_win_venv\Lib\site-packages (from requests[socks]->gdown) (2026.2.25)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in D:\-PROJECTS\venvs\time_series_forecasting_win_venv\Lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in D:\-PROJECTS\venvs\time_series_forecasting_win_venv\Lib\site-packages (from tqdm->gdown) (0.4.6)

# %%
import gdown

# Function to create a direct Google Drive download URL
def make_drive_url(file_id):
    return f"https://drive.google.com/uc?id={file_id}"

# Google Drive file IDs
file_ids = {
    "train": "PUT_TRAIN_FILE_ID_HERE"
}

# Build the download URL
train_url = make_drive_url(file_ids["train"])

# Download train.csv
gdown.download(train_url, "train.csv", quiet=False)
# Out:
# ---------------------------------------------------------------------------
# FileURLRetrievalError                     Traceback (most recent call last)
# File d:\-PROJECTS\venvs\time_series_forecasting_win_venv\Lib\site-packages\gdown\download.py:301, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, resume, format, user_agent, log_messages, progress)
#     300 try:
# --> 301     url = get_url_from_gdrive_confirmation(res.text)
#     302 except FileURLRetrievalError as e:
#
# File d:\-PROJECTS\venvs\time_series_forecasting_win_venv\Lib\site-packages\gdown\download.py:65, in get_url_from_gdrive_confirmation(contents)
#      64 if not url:
# ---> 65     raise FileURLRetrievalError(
#      66         "Cannot retrieve the public link of the file. "
#      67         "You may need to change the permission to "
#      68         "'Anyone with the link', or have had many accesses. "
#      69         "Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.",
#      70     )
#      71 return url
#
# FileURLRetrievalError: Cannot retrieve the public link of the file. You may need to change the permission to 'Anyone with the link', or have had many accesses. Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# During handling of the above exception, another exception occurred:
#
# FileURLRetrievalError                     Traceback (most recent call last)
# Cell In[4], line 16
#      12 # Build the download URL
#      13 train_url = make_drive_url(file_ids["train"])
#      14
#      15 # Download train.csv
# ---> 16 gdown.download(train_url, "train.csv", quiet=False)
#
# File d:\-PROJECTS\venvs\time_series_forecasting_win_venv\Lib\site-packages\gdown\download.py:312, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, resume, format, user_agent, log_messages, progress)
#     302     except FileURLRetrievalError as e:
#     303         message = (
#     304             "Failed to retrieve file url:\n\n{}\n\n"
#     305             "You may still be able to access the file from the browser:"
#    (...)    310             url_origin,
#     311         )
# --> 312         raise FileURLRetrievalError(message)
#     314 filename_from_url = None
#     315 last_modified_time = None
#
# FileURLRetrievalError: Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=PUT_TRAIN_FILE_ID_HERE
#
# but Gdown can't. Please check connections and permissions.
